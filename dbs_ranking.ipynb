# %%
import pandas as pd
from scipy.sparse import lil_matrix
import scipy.spatial.distance

# %%
stats = pd.read_csv('Full_NFL_Stats_2022.csv')

# %%
stats
# Out:
#       Unnamed: 0 teamName          displayName  \
# 0              0  Falcons              Fumbles
# 1              1  Falcons         Fumbles Lost
# 2              2  Falcons       Forced Fumbles
# 3              3  Falcons    Fumbles Recovered
# 4              4  Falcons   Fumbles Touchdowns
# ...          ...      ...                  ...
# 8763          18   Texans      Total Penalties
# 8764          19   Texans  Total Penalty Yards
# 8765          20   Texans      Total Takeaways
# 8766          21   Texans         Total Drives
# 8767          22   Texans       Turnover Ratio
#
#                                             description abbreviation  value  \
# 0     The number of times a player/team has fumbled ...          FUM   21.0
# 1     The number of times a fumble is recovered by t...          LST   12.0
# 2                   The total number of forced fumbles.           FF    8.0
# 3                      The number of fumbles recovered.           FR    7.0
# ...

# %%
stats.groupby('teamName')

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6352          41    Chargers     Net Yards Per Pass Attempt
# 7174          41  Buccaneers     Net Yards Per Pass Attempt
# 7448          41  Commanders     Net Yards Per Pass Attempt
# 7722          41    Panthers     Net Yards Per Pass Attempt
# 7996          41     Jaguars     Net Yards Per Pass Attempt
#
#                                             description abbreviation  \
# 5242                        The amount of games played.          TGP
# 7100                            One Point Safeties Made         OPSM
# ...

# %%
stats.dropna(subset='rank',inplace=True)

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6353          42    Chargers             Quarterback Rating
# 7175          42  Buccaneers             Quarterback Rating
# 7156          23  Buccaneers                  Passer Rating
# 4964          23      Giants                  Passer Rating
# 4983          42      Giants             Quarterback Rating
#
#                                            description abbreviation  \
# 5242                       The amount of games played.          TGP
# 7100                           One Point Safeties Made         OPSM
# ...

# %%
stats.drop(columns=['perGameValue', 'Unnamed: 0'],axis=1, inplace=True)

# %%
rows = stats.loc[stats['rank'] > 32]
print(rows)
# Out:
#      teamName            displayName                           description  \
# 2     Falcons         Forced Fumbles   The total number of forced fumbles.
# 32    Falcons          Passer Rating                         Passer Rating
# 35    Falcons   Net Passing Attempts                 Net Passing Attempts.
# 37    Falcons  Total Offensive Plays  The number of total offensive plays.
# 51    Falcons     Quarterback Rating                   Quarterback Rating.
# ...       ...                    ...                                   ...
# 8271   Ravens     Quarterback Rating                   Quarterback Rating.
# 8331   Ravens         Assist Tackles     The number of assists on tackles.
# 8353   Ravens          Total Tackles          The total number of tackles.
# 8526   Texans          Passer Rating                         Passer Rating
# 8545   Texans     Quarterback Rating                   Quarterback Rating.
#
#      abbreviation        value  rank
# ...

# %%
passdef = stats.loc[stats['displayName'] == 'Passes Defended']
passdef = passdef.sort_values(by='rank')
passdef
# Out:
#         teamName      displayName                           description  \
# 8069     Jaguars  Passes Defended  The total number of passes defended.
# 397        Bills  Passes Defended  The total number of passes defended.
# 4233     Vikings  Passes Defended  The total number of passes defended.
# 1219      Browns  Passes Defended  The total number of passes defended.
# 5603      Eagles  Passes Defended  The total number of passes defended.
# 3137      Chiefs  Passes Defended  The total number of passes defended.
# 6151    Steelers  Passes Defended  The total number of passes defended.
# 6973    Seahawks  Passes Defended  The total number of passes defended.
# 6699       49ers  Passes Defended  The total number of passes defended.
# 2589      Titans  Passes Defended  The total number of passes defended.
# 5877   Cardinals  Passes Defended  The total number of passes defended.
# 8343      Ravens  Passes Defended  The total number of passes defended.
# ...

# %%
solotackles = stats.loc[stats['displayName'] == 'Solo Tackles']
solotackles = solotackles.sort_values(by='value', ascending=False)
solotackles
# Out:
#         teamName   displayName  \
# 8622      Texans  Solo Tackles
# 4238     Vikings  Solo Tackles
# 6978    Seahawks  Solo Tackles
# 2594      Titans  Solo Tackles
# 2868       Colts  Solo Tackles
# 2046       Lions  Solo Tackles
# 1498     Cowboys  Solo Tackles
# 676        Bears  Solo Tackles
# 8074     Jaguars  Solo Tackles
# 5882   Cardinals  Solo Tackles
# 4512    Patriots  Solo Tackles
# 7252  Buccaneers  Solo Tackles
# 5608      Eagles  Solo Tackles
# 7800    Panthers  Solo Tackles
# 2320     Packers  Solo Tackles
# 3964    Dolphins  Solo Tackles
# 1772     Broncos  Solo Tackles
# 402        Bills  Solo Tackles
# 5060      Giants  Solo Tackles
# 5334        Jets  Solo Tackles
# 8348      Ravens  Solo Tackles
# 4786      Saints  Solo Tackles
# 3416     Raiders  Solo Tackles
# 3690        Rams  Solo Tackles
# 6704       49ers  Solo Tackles
# 3142      Chiefs  Solo Tackles
# 6156    Steelers  Solo Tackles
# 1224      Browns  Solo Tackles
# 128      Falcons  Solo Tackles
# ...

# %%
interceptions = stats.loc[stats['description'] == 'The total number of interceptions.']
interceptions = interceptions.sort_values(by='rank')
interceptions
# Out:
#         teamName    displayName                         description  \
# 6713       49ers  Interceptions  The total number of interceptions.
# 6165    Steelers  Interceptions  The total number of interceptions.
# 4521    Patriots  Interceptions  The total number of interceptions.
# 411        Bills  Interceptions  The total number of interceptions.
# 5617      Eagles  Interceptions  The total number of interceptions.
# 2329     Packers  Interceptions  The total number of interceptions.
# 8631      Texans  Interceptions  The total number of interceptions.
# 1507     Cowboys  Interceptions  The total number of interceptions.
# 3699        Rams  Interceptions  The total number of interceptions.
# 4247     Vikings  Interceptions  The total number of interceptions.
# 1781     Broncos  Interceptions  The total number of interceptions.
# 8083     Jaguars  Interceptions  The total number of interceptions.
# 8357      Ravens  Interceptions  The total number of interceptions.
# ...

# %%
iy = stats.loc[stats['displayName'] == 'Interception Yards']
iy = iy.sort_values(by='rank')
iy
# Out:
#         teamName         displayName  \
# 4523    Patriots  Interception Yards
# 2331     Packers  Interception Yards
# 6715       49ers  Interception Yards
# 8633      Texans  Interception Yards
# 5893   Cardinals  Interception Yards
# 3701        Rams  Interception Yards
# 8085     Jaguars  Interception Yards
# 3153      Chiefs  Interception Yards
# 687        Bears  Interception Yards
# 7811    Panthers  Interception Yards
# 5619      Eagles  Interception Yards
# 4249     Vikings  Interception Yards
# 6441    Chargers  Interception Yards
# 413        Bills  Interception Yards
# 6989    Seahawks  Interception Yards
# 2057       Lions  Interception Yards
# 6167    Steelers  Interception Yards
# 2605      Titans  Interception Yards
# 3427     Raiders  Interception Yards
# 2879       Colts  Interception Yards
# 7263  Buccaneers  Interception Yards
# 961      Bengals  Interception Yards
# 139      Falcons  Interception Yards
# 3975    Dolphins  Interception Yards
# ...

# %%
bottom_db = []

for df in [interceptions, solotackles, iy, passdef]:

    bottom_names = list(df['teamName'].tail(16))

    bottom_db += bottom_names

name_counts = {name: bottom_db.count(name) for name in set(bottom_db)}

final_names = [name for name in name_counts.keys() if name_counts[name] == 4]

print(final_names)
# Out:
# ['Saints', 'Raiders', 'Commanders', 'Falcons']
