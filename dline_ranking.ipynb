# %%
import pandas as pd
from scipy.sparse import lil_matrix
import scipy.spatial.distance

# %%
stats = pd.read_csv('Full_NFL_Stats_2022.csv')

# %%
stats
# Out:
#       Unnamed: 0 teamName          displayName  \
# 0              0  Falcons              Fumbles
# 1              1  Falcons         Fumbles Lost
# 2              2  Falcons       Forced Fumbles
# 3              3  Falcons    Fumbles Recovered
# 4              4  Falcons   Fumbles Touchdowns
# ...          ...      ...                  ...
# 8763          18   Texans      Total Penalties
# 8764          19   Texans  Total Penalty Yards
# 8765          20   Texans      Total Takeaways
# 8766          21   Texans         Total Drives
# 8767          22   Texans       Turnover Ratio
#
#                                             description abbreviation  value  \
# 0     The number of times a player/team has fumbled ...          FUM   21.0
# 1     The number of times a fumble is recovered by t...          LST   12.0
# 2                   The total number of forced fumbles.           FF    8.0
# 3                      The number of fumbles recovered.           FR    7.0
# ...

# %%
stats.groupby('teamName')

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6352          41    Chargers     Net Yards Per Pass Attempt
# 7174          41  Buccaneers     Net Yards Per Pass Attempt
# 7448          41  Commanders     Net Yards Per Pass Attempt
# 7722          41    Panthers     Net Yards Per Pass Attempt
# 7996          41     Jaguars     Net Yards Per Pass Attempt
#
#                                             description abbreviation  \
# 5242                        The amount of games played.          TGP
# 7100                            One Point Safeties Made         OPSM
# ...

# %%
stats.dropna(subset='rank',inplace=True)

# %%
stats.sort_values('rank',ascending=True)
# Out:
#       Unnamed: 0    teamName                    displayName  \
# 5242          27        Jets              Team Games Played
# 7100          15    Seahawks        One Point Safeties Made
# 4568           1    Patriots  Defensive Fumble Return Yards
# 4567           0    Patriots      Defensive Fumbles Returns
# 4563          39    Patriots              Team Games Played
# ...          ...         ...                            ...
# 6353          42    Chargers             Quarterback Rating
# 7175          42  Buccaneers             Quarterback Rating
# 7156          23  Buccaneers                  Passer Rating
# 4964          23      Giants                  Passer Rating
# 4983          42      Giants             Quarterback Rating
#
#                                            description abbreviation  \
# 5242                       The amount of games played.          TGP
# 7100                           One Point Safeties Made         OPSM
# ...

# %%
stats.drop(columns=['perGameValue', 'Unnamed: 0'],axis=1, inplace=True)

# %%
rows = stats.loc[stats['rank'] > 32]
print(rows)
# Out:
#      teamName            displayName                           description  \
# 2     Falcons         Forced Fumbles   The total number of forced fumbles.
# 32    Falcons          Passer Rating                         Passer Rating
# 35    Falcons   Net Passing Attempts                 Net Passing Attempts.
# 37    Falcons  Total Offensive Plays  The number of total offensive plays.
# 51    Falcons     Quarterback Rating                   Quarterback Rating.
# ...       ...                    ...                                   ...
# 8271   Ravens     Quarterback Rating                   Quarterback Rating.
# 8331   Ravens         Assist Tackles     The number of assists on tackles.
# 8353   Ravens          Total Tackles          The total number of tackles.
# 8526   Texans          Passer Rating                         Passer Rating
# 8545   Texans     Quarterback Rating                   Quarterback Rating.
#
#      abbreviation        value  rank
# ...

# %%
stuff = stats.loc[stats['description'] == 'The number of times that a runner is stuffed at or behind the line of scrimmage.']
stuff = stuff.sort_values(by='rank')
stuff
# Out:
#         teamName displayName  \
# 8623      Texans      Stuffs
# 403        Bills      Stuffs
# 7801    Panthers      Stuffs
# 5883   Cardinals      Stuffs
# 677        Bears      Stuffs
# 2869       Colts      Stuffs
# 7527  Commanders      Stuffs
# 8075     Jaguars      Stuffs
# 7253  Buccaneers      Stuffs
# 4239     Vikings      Stuffs
# 3417     Raiders      Stuffs
# 1499     Cowboys      Stuffs
# 6431    Chargers      Stuffs
# 2047       Lions      Stuffs
# 2595      Titans      Stuffs
# 129      Falcons      Stuffs
# 5335        Jets      Stuffs
# 1225      Browns      Stuffs
# 3965    Dolphins      Stuffs
# 2321     Packers      Stuffs
# 3143      Chiefs      Stuffs
# 6705       49ers      Stuffs
# 5061      Giants      Stuffs
# 6979    Seahawks      Stuffs
# 3691        Rams      Stuffs
# 4787      Saints      Stuffs
# 8349      Ravens      Stuffs
# 6157    Steelers      Stuffs
# 1773     Broncos      Stuffs
# 951      Bengals      Stuffs
# 5609      Eagles      Stuffs
# ...

# %%
tfl = stats.loc[stats['displayName'] == 'Tackles For Loss']
tfl = tfl.sort_values(by='rank')
tfl
# Out:
#         teamName       displayName  \
# 5611      Eagles  Tackles For Loss
# 8625      Texans  Tackles For Loss
# 405        Bills  Tackles For Loss
# 1501     Cowboys  Tackles For Loss
# 2871       Colts  Tackles For Loss
# 7529  Commanders  Tackles For Loss
# 7255  Buccaneers  Tackles For Loss
# 3145      Chiefs  Tackles For Loss
# 7803    Panthers  Tackles For Loss
# 5885   Cardinals  Tackles For Loss
# 5337        Jets  Tackles For Loss
# 4241     Vikings  Tackles For Loss
# 8077     Jaguars  Tackles For Loss
# 8351      Ravens  Tackles For Loss
# 4789      Saints  Tackles For Loss
# 6707       49ers  Tackles For Loss
# 6433    Chargers  Tackles For Loss
# 2049       Lions  Tackles For Loss
# 2597      Titans  Tackles For Loss
# 3967    Dolphins  Tackles For Loss
# 6981    Seahawks  Tackles For Loss
# 5063      Giants  Tackles For Loss
# 4515    Patriots  Tackles For Loss
# 1227      Browns  Tackles For Loss
# 3419     Raiders  Tackles For Loss
# ...

# %%
stuffyar = stats.loc[stats['displayName'] == 'Stuff Yards']
stuffyar = stuffyar.sort_values(by='rank')
stuffyar
# Out:
#         teamName  displayName                            description  \
# 5610      Eagles  Stuff Yards  The number of yards lost from stuffs.
# 3144      Chiefs  Stuff Yards  The number of yards lost from stuffs.
# 1500     Cowboys  Stuff Yards  The number of yards lost from stuffs.
# 4514    Patriots  Stuff Yards  The number of yards lost from stuffs.
# 7254  Buccaneers  Stuff Yards  The number of yards lost from stuffs.
# 6706       49ers  Stuff Yards  The number of yards lost from stuffs.
# 5336        Jets  Stuff Yards  The number of yards lost from stuffs.
# 8350      Ravens  Stuff Yards  The number of yards lost from stuffs.
# 6980    Seahawks  Stuff Yards  The number of yards lost from stuffs.
# 3966    Dolphins  Stuff Yards  The number of yards lost from stuffs.
# 404        Bills  Stuff Yards  The number of yards lost from stuffs.
# 6432    Chargers  Stuff Yards  The number of yards lost from stuffs.
# 6158    Steelers  Stuff Yards  The number of yards lost from stuffs.
# ...

# %%
sacks = stats.loc[stats['displayName'] == 'Sacks']
sacks = sacks.sort_values(by='rank')
sacks
# Out:
#         teamName displayName                 description abbreviation  value  \
# 5605      Eagles       Sacks  The total number of sacks.         SACK   70.0
# 3139      Chiefs       Sacks  The total number of sacks.         SACK   55.0
# 4509    Patriots       Sacks  The total number of sacks.         SACK   54.0
# 1495     Cowboys       Sacks  The total number of sacks.         SACK   54.0
# 8345      Ravens       Sacks  The total number of sacks.         SACK   48.0
# 4783      Saints       Sacks  The total number of sacks.         SACK   48.0
# 5331        Jets       Sacks  The total number of sacks.         SACK   45.0
# 6975    Seahawks       Sacks  The total number of sacks.         SACK   45.0
# 7249  Buccaneers       Sacks  The total number of sacks.         SACK   44.0
# 2865       Colts       Sacks  The total number of sacks.         SACK   44.0
# 6701       49ers       Sacks  The total number of sacks.         SACK   44.0
# ...

# %%
bottom_dline = []

for df in [stuffyar, tfl, sacks, stuff]:

    bottom_names = list(df['teamName'].tail(16))

    bottom_dline += bottom_names

name_counts = {name: bottom_dline.count(name) for name in set(bottom_dline)}

final_names = [name for name in name_counts.keys() if name_counts[name] == 4]

print(final_names)
# Out:
# ['Browns', 'Broncos', 'Bengals', 'Rams', 'Packers']
